# %%
import pandas as pd
import glob
import re
from functools import reduce
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetlemmatizer
from collections import counter
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 7
#       5 from nltk.tokenize import word_tokenize
#       6 from nltk.corpus import stopwords
# ----> 7 from nltk.stem import WordNetlemmatizer
#       8 from collections import counter
#       9 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'WordNetlemmatizer' from 'nltk.stem' (/opt/anaconda3/lib/python3.13/site-packages/nltk/stem/__init__.py)

# %%
all_files = glob.glob('Desktop/Git/파이썬프로그래밍/8장_data/myCabinetExcelData.xlsx')
all_files
# Out:
# []

# %%
all_files_data = []
for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)
    
all_files_data[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 6
#       3     data_frame = pd.read_excel(file)
#       4     all_files_data.append(data_frame)
# ----> 6 all_files_data[0]
#
# IndexError: list index out of range

# %%
all_files_data_concat = pd.concat(all_files_data, axis = 0,
                                  ignore_index = True)
all_files_data_concat
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 all_files_data_concat = pd.concat(all_files_data, axis = 0,
#       2                                   ignore_index = True)
#       3 all_files_data_concat
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
# ...

# %%
all_files_data_concat.to_csv('Desktop/Git/파이썬프로그래밍/8장_data/riss_bigdata.xlsx',
                             encoding = 'utf-8', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 all_files_data_concat.to_csv('Desktop/Git/파이썬프로그래밍/8장_data/riss_bigdata.xlsx',
#       2                              encoding = 'utf-8', index = False)
#
# NameError: name 'all_files_data_concat' is not defined

# %%
all_title = all_files_data_concat['제목']
all_title
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 all_title = all_files_data_concat['제목']
#       2 all_title
#
# NameError: name 'all_files_data_concat' is not defined

# %%
stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 stopWords = set(stopwords.words("english"))
#       2 lemma = WordNetLemmatizer()
#
# NameError: name 'stopwords' is not defined

# %%
words = []
for title in all_title:
    EnWords = re.sub(r"[^a-zA-Z]+", " ", str(title))
    EnWordsToKen = word_tokenize(EnWords.lower())
    EnWordsTokenStop = [w for w in EnWordsToken if w not in stopWords]
    EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in EnWordsTokeStop]
    words.append(EnWordsTokenStopLemma)

print(words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 words = []
# ----> 2 for title in all_title:
#       3     EnWords = re.sub(r"[^a-zA-Z]+", " ", str(title))
#       4     EnWordsToKen = word_tokenize(EnWords.lower())
#
# NameError: name 'all_title' is not defined

# %%
from nltk.stem import WordNetLemmatizer

# 1. WordNetLemmatizer 객체 생성
lemmatizer = WordNetLemmatizer()

# # 2. 명사(n)로 지정하여 표제어 추출
word1 = "geese"
print(f"'word1'의 표제어 (명사): {lemmatizer.lemmatize(word1, 'n')}")
# 출력: 'geese'의 표제어 (명사): goose

# # 3. 동사(v)로 지정하여 표제어 추출
word2 = "running"
print(f"'word2'의 표제어 (동사): {lemmatizer.lemmatize(word2, 'v')}")
# 출력: 'running'의 표제어 (동사): run

# 4. 품사(PoS)를 지정하지 않으면 명사로 가정함
word3 = "better"
print(f"'word3'의 표제어 (기본): {lemmatizer.lemmatize(word3)}")
# 출력: 'better'의 표제어 (기본): better
print(f"'word3'의 표제어 (형용사): {lemmatizer.lemmatize(word3, 'a')}")
# 출력: 'better'의 표제어 (형용사): good
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 ㅇㅇ
#
# NameError: name 'ᄋᄋ' is not defined

# %%
words2 = list(reduce(lambda x, y: x+y, words))
print(words2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 words2 = list(reduce(lambda x, y: x+y, words))
#       2 print(words2)
#
# TypeError: reduce() of empty iterable with no initial value

# %%
count = Counter(words2)

count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 count = Counter(words2)
#       3 count
#
# NameError: name 'Counter' is not defined

# %%
word_count = dict()

for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 word_count = dict()
# ----> 3 for tag, counts in count.most_common(50):
#       4     if(len(str(tag))>1):
#       5         word_count[tag] = counts
#
# NameError: name 'count' is not defined

# %%
sorted_Keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = 85)
plt.show()

# %%
all_files_data_concat['doc_count'] = 0
summary_year = all_files_data_concat.groupby('출판일',
                                             as_index = False)['doc_count'].count()

summary_year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 all_files_data_concat['doc_count'] = 0
#       2 summary_year = all_files_data_concat.groupby('출판일',
#       3                                              as_index = False)['doc_count'].count()
#       5 summary_year
#
# NameError: name 'all_files_data_concat' is not defined

# %%
plt.figure(figsize = (12, 5))
plt.xlabel ("year")
plt.ylabel ("doc-count")
plt.grid(True)
plt.plot(range(len(summary_year)), summary_year['doc_count'])
plt xticks(range(len(summary _year)), Itext for text in summary_
year['출판일']])
plt.show ()
# Out:
#   Cell In[25], line 7
#     year['출판일']])
#                ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '(' on line 6

# %%
stopwords = set(STOPWORDS )
wc = WordCloud (background_color = 'ivory', stopwords = stopwords,
width = 800, height = 600)
cloud = wc.generate_from_frequencies(word_count)
plt. figure(figsize = (8,8))
plt. imshow(cloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 stopwords = set(STOPWORDS )
#       2 wc = WordCloud (background_color = 'ivory', stopwords = stopwords,
#       3 width = 800, height = 600)
#       4 cloud = wc.generate_from_frequencies(word_count)
#
# NameError: name 'STOPWORDS' is not defined

# %%
cloud.to_file("8%_data/riss_bigdata_wordCloud.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cloud.to_file("8%_data/riss_bigdata_wordCloud.jpg")
#
# NameError: name 'cloud' is not defined

# %%
#검색어로 사용한 big'과 'data' 함 제거 하기
del word_count ['big'] del word_count ['data']
# 히스토그램 표시 옵션
plt. figure(figsize=(12,5))
plt. xlabel ("word")
plt. ylabel ("count" )
plt. grid(True)
sorted_Keys = sorted(word_count, key=word_count.get, reverse-True)
sorted_Values = sorted(word_count values(), reverse=True)
plt.bar(range(len(word_count)), sorted_Values, align='center') plt.xticks(range(len(word_count)), list(sorted_Keys), rotation=85)
plt. show()
# Out:
#   Cell In[28], line 2
#     del word_count ['big'] del word_count ['data']
#                            ^
# SyntaxError: invalid syntax

# %%
import json 
import re
from konlpy.tag import Okt 
from collections import Counter 
import matplotlib
import matplotlib.pyplot as plt 
from matplotlib import font_manager, rc 
from wordcloud import WordCloud 
inputFileName = '아시안컵_naver_news'
data = json.loads(open(inputFileNamet'.json', 'r', encoding ='utf-8').read())
data # 작업 확인용 출력
# Out:
#   Cell In[29], line 1
#     import json import re
#                 ^
# SyntaxError: invalid syntax

# %%
description = ''
for item in data:
    if 'description' in item.keys():
        description = description + re. sub(r'[^\w', '', item'description']) + ''
description # 작업 확인용 출력
# Out:
#   Cell In[30], line 5
#     item'description']) + ''
#                      ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '(' on line 4

# %%
nlp = 0kt()
description_N = nlp.nouns (description)
description_N # 작업 확인용 출력
# Out:
#   Cell In[31], line 1
#     nlp = 0kt()
#           ^
# SyntaxError: invalid decimal literal

# %%
count = Counter(description_N)
count # 작업 확인용 출력
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 count = Counter(description_N)
#       2 count # 작업 확인용 출력
#
# NameError: name 'Counter' is not defined

# %%
word_count = dict()
for tag, counts in count.most_common (100):
    if(len(str(tag))>1):
        word_count |tag] = counts
print ("is : 8d" % (tag, counts))
# Out:
#   Cell In[33], line 4
#     word_count |tag] = counts
#                    ^
# SyntaxError: unmatched ']'

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
plt.figure(figsize = (12, 5))
plt.xlabel('키워드')
plt.ylabel('빈도수')
plt.grid(True)
sorted_Keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar (range(len(word_count)), sorted_Values, align = 'center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = 75)
plt.show()
# Out:
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 53412 (\N{HANGUL SYLLABLE KI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50892 (\N{HANGUL SYLLABLE WEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
import json 
import re
from konlpy.tag import Okt 
from collections import Counter 
import matplotlib
import matplotlib.pyplot as plt 
from matplotlib import font_manager, rc 
from wordcloud import WordCloud 

wc = WordCloud(font_path, background_color = 'ivory', width = 800,
height = 600)
cloud = wc.generate_from_frequencies(word_count)
plt. figure(figsize = (8, 8))
plt. imshow(cloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       7 from matplotlib import font_manager, rc
#       8 from wordcloud import WordCloud
# ---> 10 wc = WordCloud(font_path, background_color = 'ivory', width = 800,
#      11 height = 600)
#      12 cloud = wc.generate_from_frequencies(word_count)
#      13 plt. figure(figsize = (8, 8))
#
# NameError: name 'font_path' is not defined
